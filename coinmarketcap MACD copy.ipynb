# %%
def data_preprocessor(date_element):
    return "-".join(date_element.split('-')[:2])
data_preprocessor("2018-02-21")
# Out:
# '2018-02'

# %%
import quandl 
import pandas as pd 
import requests
SO = requests.get("https://api.coingecko.com/api/v3/coins/bitcoin/ohlc?vs_currency=usd&days=1").json()
SO = pd.DataFrame(SO, columns=["volume","open","high","low","close (USD)"])
SO = pd.DataFrame(SO)

# %%
SO.head()
# Out:
#           volume      open      high       low  close (USD)
# 0  1605724200000  17952.96  17970.68  17863.36     17886.12
# 1  1605726000000  17853.52  17900.49  17806.36     17806.36
# 2  1605727800000  17786.32  17828.46  17736.48     17761.03
# 3  1605729600000  17657.51  17710.84  17598.00     17598.00
# 4  1605731400000  17639.66  17691.52  17595.87     17617.70

# %%
import matplotlib.pyplot as plt 
fig, ax = plt.subplots(figsize=[10,10])
# SO["close (USD)"].plot(grid=True)
plt.plot( SO["close (USD)"])
plt.title("BTC USD Closing prices")

plt.show()

# %%
import numpy as np

short_window = 12
long_window = 26

signals = pd.DataFrame(SO.index)
signals['signal'] = 0.0

#EMA of short window
signals['short_mavg'] = SO['close (USD)'].ewm(span = short_window, adjust = False).mean()

#EMA of long window
signals['long_mavg'] = SO['close (USD)'].ewm(span = long_window, adjust = False).mean()

#Create signals
signals['signal'][short_window:] = np.where(signals["short_mavg"][short_window:] > signals["long_mavg"][short_window:], 1.0, 0.0)

#generate trading orders 
signals["positions"] = signals["signal"].diff()

# %%
import matplotlib.pyplot as plt 
fig = plt.figure(figsize=(20,15))

ax1 = fig.add_subplot(111, ylabel="Price in $")

SO["close (USD)"].plot(ax=ax1, color='black', lw = 2.)

signals[["short_mavg", "long_mavg"]].plot(ax=ax1, lw=2.)

#Plot the buy signals
ax1.plot(signals.loc[signals["positions"] == 1.0].index, signals.short_mavg[signals.positions == 1.0], '^', markersize=20)

#Plot the sell signals
ax1.plot(signals.loc[signals["positions"] == -1.0].index, signals.short_mavg[signals.positions == -1.0], '^', markersize=20)

# %%
initial_capital = float(10000)

positions = pd.DataFrame(index=signals.index).fillna(0.0)

positions["Position in HKD"] = 1*signals['signal']

portfolio = positions.multiply(SO["close (USD)"], axis=0)

poss_diff = positions.diff()

portfolio["holdings"] = (positions.multiply(SO["close (USD)"], axis=0)).sum(axis=1)

portfolio["cash"] = initial_capital - (poss_diff.multiply(SO["close (USD)"], axis=0)).sum(axis=1).cumsum()

portfolio["total"] = portfolio["cash"] + portfolio["holdings"]

portfolio["returns"] = portfolio["total"].pct_change()

del portfolio["Position in HKD"]

print(portfolio.tail())
# Out:
#      holdings    cash     total   returns
# 395  15684.24 -177.01  15507.23  0.025597
# 396  16291.86 -177.01  16114.85  0.039183
# 397  16320.70 -177.01  16143.69  0.001790
# 398  16070.45 -177.01  15893.44 -0.015501
# 399  16072.55 -177.01  15895.54  0.000132

# %%
fig = plt.figure(figsize=(20,15))

ax1 = fig.add_subplot(111, ylabel="Portfolio value in $")

# ax2 = fig.add_subplot(111, ylabel="Returns $")
# plot equit portfolio in $
portfolio["total"].plot(ax=ax1, lw=2., color='black')

#btc price
SO["close (USD)"].plot(ax=ax1, color='blue', lw = 2.)


ax1.plot(portfolio.loc[signals.positions==1.0].index,portfolio.total[signals.positions ==1.0], '^', markersize=20, color='g')

ax1.plot(portfolio.loc[signals.positions==-1.0].index,portfolio.total[signals.positions ==-1.0], 'v', markersize=20, color='r')

# %%
#total portfolio value
print("Portfolio value as of Nov 2020 after investing 10k in 2018")
print(portfolio['total'].tail(1))

print("Absolute return as of May 2018")
print(((portfolio['total'].tail(1)/float(10000)) -float(1))*100)
# Out:
# Portfolio value as of Nov 2020 after investing 10k in 2018
# 399    15895.54
# Name: total, dtype: float64
# Absolute return as of May 2018
# 399    58.9554
# Name: total, dtype: float64

# %%
import pandas as pd
from ta.utils import dropna
from ta.trend import SMAIndicator

coinData = pd.DataFrame(data, columns=['MarketCAP','Open','High','Low','Close'])

smaInd = SMAIndicator(coinData["Close"], 3)

print(smaInd.sma_indicator())
# Out:
# 0              NaN
# 1              NaN
# 2     15191.730000
# 3     15356.120000
# 4     15479.080000
# 5     15488.660000
# 6     15451.606667
# 7     15439.150000
# 8     15331.070000
# 9     15297.910000
# 10    15234.236667
# 11    15290.816667
# 12    15305.043333
# 13    15318.186667
# 14    15301.996667
# 15    15293.026667
# 16    15311.316667
# 17    15353.716667
# 18    15375.970000
# 19    15425.903333
# 20    15496.980000
# 21    15642.810000
# 22    15721.003333
# 23    15726.693333
# 24    15722.770000
# 25    15727.006667
# 26    15834.086667
# 27    15932.120000
# 28    16087.113333
# 29    16245.333333
# 30    16312.853333
# 31    16275.216667
# 32    16201.013333
# 33    16189.890000
# 34    16250.520000
# 35    16245.826667
# 36    16219.393333
# 37    16065.736667
# 38    16011.310000
# 39    15921.480000
# 40    15987.136667
# 41    15980.040000
# 42    15990.930000
# Name: sma_3, dtype: float64

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import plotly.graph_objects as go
import json

url = 'https://api.coingecko.com/api/v3/coins/bitcoin/ohlc?vs_currency=usd&days=7'


try:
  response = session.get(url)
  data = json.loads(response.text)
  coinData = pd.DataFrame(data, columns=['MarketCAP','Open','High','Low','Close'])
  print(data)
  fig = go.Figure(data=go.Ohlc(x=df['Date'],
                    open=df['AAPL.Open'],
                    high=df['AAPL.High'],
                    low=df['AAPL.Low'],
                    close=df['AAPL.Close']))
  
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# [[1604822400000, 15032.68, 15032.68, 15004.09, 15004.09], [1604836800000, 14946.22, 15137.89, 14946.22, 15137.89], [1604851200000, 15148.12, 15433.21, 15148.12, 15433.21], [1604865600000, 15315.02, 15561.6, 15315.02, 15497.26], [1604880000000, 15404.77, 15506.77, 15316.21, 15506.77], [1604894400000, 15467.51, 15563.16, 15461.95, 15461.95], [1604908800000, 15445.25, 15449.8, 15366.78, 15386.1], [1604923200000, 15299.29, 15469.4, 15299.29, 15469.4], [1604937600000, 15783.91, 15783.91, 15137.71, 15137.71], [1604952000000, 15016.17, 15286.62, 15016.17, 15286.62], [1604966400000, 15387.82, 15387.82, 15278.38, 15278.38], [1604980800000, 15283.59, 15388.12, 15282.04, 15307.45], [1604995200000, 15349.6, 15391.56, 15329.3, 15329.3], [1605009600000, 15291.47, 15358.15, 15291.47, 15317.81], [1605024000000, 15264.18, 15312.52, 15258.88, 15258.88], [1605038400000, 15217.7, 15302.39, 15217.7, 15302.39], [1605052800000, 15316.44, 15372.68, 15316.44, 15372.68], [1605067200000, 15290.06, 15447.44, 15290.06, 15386.08], [1605081600000, 15414.6, 15414.6, 15369.15, 15369.15], [1605096000000, 15405.13, 15522.48, 15374.68, 15522.48], [1605110400000, 15542.03, 15642.56, 15542.03, 15599.31], [1605124800000, 15719.56, 15907.38, 15719.56, 15806.64], [1605139200000, 15796.39, 15796.39, 15692.39, 15757.06], [1605153600000, 15686.91, 15686.91, 15616.38, 15616.38], [1605168000000, 15654.97, 15794.87, 15654.97, 15794.87], [1605182400000, 15896.08, 16131.84, 15769.77, 15769.77], [1605196800000, 15791.6, 16051.33, 15791.6, 15937.62], [1605211200000, 16093.86, 16140.44, 15999.67, 16088.97], [1605225600000, 16075.81, 16234.75, 16075.81, 16234.75], [1605240000000, 16275.64, 16422.26, 16275.64, 16412.28], [1605254400000, 16414.75, 16414.75, 16250.97, 16291.53], [1605268800000, 16268.47, 16325.98, 16121.84, 16121.84], [1605283200000, 16230.84, 16244.77, 16189.67, 16189.67], [1605297600000, 16137.34, 16258.16, 16137.34, 16258.16], [1605312000000, 16278.35, 16303.73, 16245.53, 16303.73], [1605326400000, 16288.3, 16288.3, 16175.59, 16175.59], [1605340800000, 16186.31, 16186.31, 16142.98, 16178.86], [1605355200000, 16084.98, 16084.98, 15797.65, 15842.76], [1605369600000, 15929.75, 16012.31, 15919.21, 16012.31], [1605384000000, 15999.45, 15999.45, 15833.46, 15909.37], [1605398400000, 15900.92, 16039.73, 15900.92, 16039.73], [1605412800000, 16095.56, 16095.56, 15991.02, 15991.02], [1605427200000, 15919.66, 15942.04, 15919.66, 15942.04]]
# 43
